# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine_hdb = create_engine('mysql://airflow_user:password@localhost:3306/HDB_Data')

str_sql = f'''
SELECT * FROM raw_onemap_planning_areas
'''
df_planning_area = pd.read_sql(sql=str_sql, con=engine_hdb)

str_sql = f'''
SELECT * FROM raw_onemap_transport_school
'''
df_transport_school = pd.read_sql(sql=str_sql, con=engine_hdb)

str_sql = f'''
SELECT * FROM raw_onemap_transport_work
'''
df_transport_work = pd.read_sql(sql=str_sql, con=engine_hdb)

str_sql = f'''
SELECT * FROM raw_onemap_dwelling
'''
df_dwelling = pd.read_sql(sql=str_sql, con=engine_hdb)

str_sql = f'''
SELECT * FROM raw_onemap_tenancy
'''
df_tenancy = pd.read_sql(sql=str_sql, con=engine_hdb)

engine_hdb.dispose()

# %% [markdown]
# ## **Finding DataFrames with Nulls**

# %%
for df in [df_planning_area, df_transport_school, df_transport_work, df_dwelling, df_tenancy]:
    print(df.isna().sum())
# Out:
# planning_area    0
# year             0
# _fp              0
# dtype: int64
# planning_area                  0
# year                           0
# bus                           42
# mrt                           42
# mrt_bus                       42
# mrt_car                       42
# mrt_other                     42
# taxi                          42
# car                           42
# pvt_chartered_bus             42
# lorry_pickup                  42
# motorcycle_scooter            42
# others                        42
# no_transport_required         42
# other_combi_mrt_or_bus        42
# mrt_lrt_only                  42
# mrt_lrt_and_bus               42
# other_combi_mrt_lrt_or_bus    42
# taxi_pvt_hire_car_only        42
# pvt_chartered_bus_van         42
# _fp                            0
# dtype: int64
# planning_area                  0
# year                           0
# bus                           42
# mrt                           42
# ...

# %%
df_transport_school[df_transport_school.isnull().any(axis=1)]
# Out:
#                planning_area  year   bus   mrt mrt_bus mrt_car mrt_other  \
# 12                  BOON LAY  2010  None  None    None    None      None
# 15          BOON LAY/PIONEER  2000  None  None    None    None      None
# 32   CENTRAL WATER CATCHMENT  2000  None  None    None    None      None
# 33   CENTRAL WATER CATCHMENT  2010  None  None    None    None      None
# 40                CHANGI BAY  2000  None  None    None    None      None
# 41                CHANGI BAY  2010  None  None    None    None      None
# 76              LIM CHU KANG  2000  None  None    None    None      None
# 77              LIM CHU KANG  2010  None  None    None    None      None
# 80                    MANDAI  2000  None  None    None    None      None
# 84               MARINA EAST  2000  None  None    None    None      None
# 85               MARINA EAST  2010  None  None    None    None      None
# 88              MARINA SOUTH  2000  None  None    None    None      None
# ...

# %%
df_transport_work[df_transport_work.isnull().any(axis=1)]
# Out:
#                planning_area  year   bus   mrt mrt_bus mrt_car mrt_other  \
# 12                  BOON LAY  2010  None  None    None    None      None
# 15          BOON LAY/PIONEER  2000  None  None    None    None      None
# 32   CENTRAL WATER CATCHMENT  2000  None  None    None    None      None
# 33   CENTRAL WATER CATCHMENT  2010  None  None    None    None      None
# 40                CHANGI BAY  2000  None  None    None    None      None
# 41                CHANGI BAY  2010  None  None    None    None      None
# 76              LIM CHU KANG  2000  None  None    None    None      None
# 77              LIM CHU KANG  2010  None  None    None    None      None
# 80                    MANDAI  2000  None  None    None    None      None
# 84               MARINA EAST  2000  None  None    None    None      None
# 85               MARINA EAST  2010  None  None    None    None      None
# 88              MARINA SOUTH  2000  None  None    None    None      None
# ...

# %%
df_tenancy[df_tenancy.isnull().any(axis=1)]
# Out:
#                planning_area  year owner tenant others  \
# 12                  BOON LAY  2010  None   None   None
# 15          BOON LAY/PIONEER  2000  None   None   None
# 32   CENTRAL WATER CATCHMENT  2000  None   None   None
# 33   CENTRAL WATER CATCHMENT  2010  None   None   None
# 40                CHANGI BAY  2000  None   None   None
# 41                CHANGI BAY  2010  None   None   None
# 76              LIM CHU KANG  2000  None   None   None
# 77              LIM CHU KANG  2010  None   None   None
# 80                    MANDAI  2000  None   None   None
# 84               MARINA EAST  2000  None   None   None
# 85               MARINA EAST  2010  None   None   None
# 88              MARINA SOUTH  2000  None   None   None
# 89              MARINA SOUTH  2010  None   None   None
# 96                    MUSEUM  2000  None   None   None
# 97                    MUSEUM  2010  None   None   None
# 104    NORTH-EASTERN ISLANDS  2000  None   None   None
# ...

# %%
df_dwelling[df_dwelling.isnull().any(axis=1)]
# Out:
#                planning_area  year hdb_1_and_2_room_flats hdb_3_room_flats  \
# 12                  BOON LAY  2010                   None             None
# 13                  BOON LAY  2015                   None             None
# 15          BOON LAY/PIONEER  2000                   None             None
# 32   CENTRAL WATER CATCHMENT  2000                   None             None
# 33   CENTRAL WATER CATCHMENT  2010                   None             None
# ..                       ...   ...                    ...              ...
# 204          WESTERN ISLANDS  2010                   None             None
# 205          WESTERN ISLANDS  2015                   None             None
# 207  WESTERN WATER CATCHMENT  2000                   None             None
# 208  WESTERN WATER CATCHMENT  2010                   None             None
# 209  WESTERN WATER CATCHMENT  2015                   None             None
#
#     hdb_4_room_flats hdb_5_room_and_executive_flats  \
# ...

# %% [markdown]
# ## **Exploratory Data Analysis on Type of Dwelling**

# %%
df_dwelling = df_dwelling.fillna(0)

dwelling_cols = [
    'hdb_1_and_2_room_flats',
    'hdb_3_room_flats',
    'hdb_4_room_flats',
    'hdb_5_room_and_executive_flats',
    'condominiums_and_other_apartments',
    'landed_properties',
    'others'
]

df_dwelling[dwelling_cols] = df_dwelling[dwelling_cols].apply(
    pd.to_numeric, errors='coerce'
)

# %%
df_dwelling['total_dwelling_units'] = df_dwelling[dwelling_cols].sum(axis=1)

df_dwelling['pct_hdb_1_and_2_room_flats'] = df_dwelling['hdb_1_and_2_room_flats'] / df_dwelling['total_dwelling_units']
df_dwelling['pct_hdb_3_room_flats'] = df_dwelling['hdb_3_room_flats'] / df_dwelling['total_dwelling_units']
df_dwelling['pct_hdb_4_room_flats'] = df_dwelling['hdb_4_room_flats'] / df_dwelling['total_dwelling_units']
df_dwelling['pct_hdb_5_room_and_executive_flats'] = df_dwelling['hdb_5_room_and_executive_flats'] / df_dwelling['total_dwelling_units']
df_dwelling['pct_condominiums_and_other_apartments'] = df_dwelling['condominiums_and_other_apartments'] / df_dwelling['total_dwelling_units']
df_dwelling['pct_landed_properties'] = df_dwelling['landed_properties'] / df_dwelling['total_dwelling_units']

# %%
df_dwelling_2020 = df_dwelling[df_dwelling['year'] == '2020'].copy() # note that year is a string, not an integer

pct_cols = [col for col in df_dwelling_2020.columns if col.startswith('pct_')]

for col in pct_cols:
    s = pd.to_numeric(df_dwelling_2020[col], errors='coerce')
    s = s[s > 0]   # exclude zeros and NaNs

    if s.empty:
        print(f"\n{col}")
        print("No positive values in 2020")
        continue

    max_idx = s.idxmax()
    min_idx = s.idxmin()

    max_row = df_dwelling_2020.loc[max_idx]
    min_row = df_dwelling_2020.loc[min_idx]

    print(f"\n{col}")
    print(f"Highest: {max_row['planning_area']} ({max_row[col]})")
    print(f"Lowest: {min_row['planning_area']} ({min_row[col]})")
# Out:
# pct_hdb_1_and_2_room_flats
# Highest: OUTRAM (0.35879284649776455)
# Lowest: BUKIT TIMAH (0.005972696245733789)
#
# pct_hdb_3_room_flats
# Highest: ANG MO KIO (0.39998339422118895)
# Lowest: TANGLIN (0.0026455026455026454)
#
# pct_hdb_4_room_flats
# Highest: YISHUN (0.4254870495868865)
# Lowest: TANGLIN (0.009952128999748048)
#
# pct_hdb_5_room_and_executive_flats
# Highest: PASIR RIS (0.3834992633599714)
# Lowest: TANGLIN (0.010833963214915596)
#
# pct_condominiums_and_other_apartments
# Highest: RIVER VALLEY (0.9358651911468813)
# Lowest: OUTRAM (0.05216095380029806)
#
# pct_landed_properties
# Highest: BUKIT TIMAH (0.37229806598407283)
# Lowest: PUNGGOL (0.0012285231015757144)

# %% [markdown]
# ## **Exploratory Data Analysis on Transport to School**

# %%
df_transport_school = df_transport_school.fillna(0)

transport_school_cols = [
    'bus', 'mrt', 'mrt_bus', 'mrt_car',
    'mrt_other', 'taxi', 'car', 'pvt_chartered_bus', 'lorry_pickup',
    'motorcycle_scooter', 'others', 'no_transport_required',
    'other_combi_mrt_or_bus', 'mrt_lrt_only', 'mrt_lrt_and_bus',
    'other_combi_mrt_lrt_or_bus', 'taxi_pvt_hire_car_only',
    'pvt_chartered_bus_van'
]

df_transport_school[transport_school_cols] = df_transport_school[transport_school_cols].apply(
    pd.to_numeric, errors='coerce'
)

# %%
df_transport_school['total_transport_school'] = df_transport_school[transport_school_cols].sum(axis=1)

df_transport_school['pct_bus'] = df_transport_school['bus'] / df_transport_school['total_transport_school']
df_transport_school['pct_mrt'] = df_transport_school['mrt'] / df_transport_school['total_transport_school']
df_transport_school['pct_mrt_bus'] = df_transport_school['mrt_bus'] / df_transport_school['total_transport_school']
df_transport_school['pct_car'] = df_transport_school['car'] / df_transport_school['total_transport_school']
df_transport_school['pct_mrt_lrt_only'] = df_transport_school['mrt_lrt_only'] / df_transport_school['total_transport_school']
df_transport_school['pct_mrt_lrt_and_bus'] = df_transport_school['mrt_lrt_and_bus'] / df_transport_school['total_transport_school']

# %%
df_transport_school_2020 = df_transport_school[df_transport_school['year'] == '2020'].copy() # note that year is a string, not an integer

pct_cols = [col for col in df_transport_school_2020.columns if col.startswith('pct_')]

for col in pct_cols:
    s = pd.to_numeric(df_transport_school_2020[col], errors='coerce')
    s = s[s > 0]   # exclude zeros and NaNs

    if s.empty:
        print(f"\n{col}")
        print("No positive values in 2020")
        continue

    max_idx = s.idxmax()
    min_idx = s.idxmin()

    max_row = df_transport_school_2020.loc[max_idx]
    min_row = df_transport_school_2020.loc[min_idx]

    print(f"\n{col}")
    print(f"Highest: {max_row['planning_area']} ({max_row[col]})")
    print(f"Lowest: {min_row['planning_area']} ({min_row[col]})")
# Out:
# pct_bus
# Highest: JURONG EAST (0.33772958977263534)
# Lowest: RIVER VALLEY (0.09216589861751152)
#
# pct_mrt
# No positive values in 2020
#
# pct_mrt_bus
# No positive values in 2020
#
# pct_car
# Highest: TANGLIN (0.364103819784525)
# Lowest: WOODLANDS (0.06902245041779925)
#
# pct_mrt_lrt_only
# Highest: DOWNTOWN CORE (0.23214285714285715)
# Lowest: MARINE PARADE (0.02807060554057367)
#
# pct_mrt_lrt_and_bus
# Highest: CHOA CHU KANG (0.3073444565725869)
# Lowest: TANGLIN (0.09720861900097943)
