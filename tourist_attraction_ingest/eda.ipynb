# %% [markdown]
# Call the API to the dataset and fetch the data from the API

# %%
import requests
import pandas as pd
import io

dataset_id = "d_0f2f47515425404e6c9d2a040dd87354"
url = "https://api-open.data.gov.sg/v1/public/api/datasets/" + dataset_id + "/poll-download"

response = requests.get(url)
json_data = response.json()
if json_data['code'] != 0:
    print(json_data['errMsg'])
    exit(1)

download_url = json_data['data']['url']
response = requests.get(download_url)

# Try CSV first (common for data.gov.sg), fallback to JSON
try:
    df = pd.read_csv(io.StringIO(response.text))
except (ValueError, pd.errors.ParserError):
    data = response.json()
    if isinstance(data, list):
        df = pd.DataFrame(data)
    elif "records" in data:
        df = pd.DataFrame(data["records"])
    elif "result" in data and "records" in data["result"]:
        df = pd.DataFrame(data["result"]["records"])
    else:
        df = pd.json_normalize(data)

# Flatten GeoJSON FeatureCollection if present
if "features" in df.columns and len(df) > 0:
    first = df.iloc[0]
    if first.get("type") == "FeatureCollection" and isinstance(first.get("features"), list):
        rows = []
        for feat in first["features"]:
            row = dict(feat.get("properties", {}))
            geom = feat.get("geometry", {})
            if geom.get("type") == "Point" and "coordinates" in geom:
                row["longitude"] = geom["coordinates"][0]
                row["latitude"] = geom["coordinates"][1]
            rows.append(row)
        df = pd.DataFrame(rows)

df
# Out:
#      OBJECTID_1                                           URL_PATH  \
# 0          1001  www.yoursingapore.com/en/see-do-singapore/arts...
# 1          1002  www.yoursingapore.com/en/see-do-singapore/cult...
# 2          1003  www.yoursingapore.com/en/see-do-singapore/cult...
# 3          1004  www.yoursingapore.com/en/see-do-singapore/cult...
# 4          1005  www.yoursingapore.com/en/see-do-singapore/arch...
# ..          ...                                                ...
# 104         996  www.yoursingapore.com/en/see-do-singapore/natu...
# 105         997  www.yoursingapore.com/en/see-do-singapore/natu...
# 106         998  www.yoursingapore.com/en/see-do-singapore/plac...
# 107         999  www.yoursingapore.com/en/see-do-singapore/plac...
# 108        1000  www.yoursingapore.com/en/see-do-singapore/plac...
#
#                                             IMAGE_PATH  \
# 0    www.yoursingapore.com/content/dam/desktop/glob...
# 1                                                  NaN
# 2    www.yoursingapore.com/content/dam/desktop/glob...
# 3    www.yoursingapore.com/content/dam/desktop/glob...
# 4    www.yoursingapore.com/content/dam/desktop/glob...
# ..                                                 ...
# 104  www.yoursingapore.com/content/dam/desktop/glob...
# 105  www.yoursingapore.com/content/dam/desktop/glob...
# 106  www.yoursingapore.com/content/dam/desktop/glob...
# 107  www.yoursingapore.com/content/dam/desktop/glob...
# 108  www.yoursingapore.com/content/dam/desktop/glob...
#
#                                         IMAGE_ALT_TEXT  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Sri Mariamman Temple's ornate and elaborate de...
# 3    The Armenian Church in Singapore is a 19th-cen...
# 4    The charm of CHIJMES, Singapore harks back to ...
# ..                                                 ...
# 104  MacRitchie Reservoir is natureâ€™s playground ...
# 105  Be mesmerised by stunning waterfront views at ...
# 106  Immerse yourself in a day of history and cultu...
# 107  HarbourFront, Singapore is your exciting gatew...
# 108  Thereâ€™s nowhere else quite like shopping at ...
#
#                       PHOTOCREDITS  \
# 0    Â©Darren Soh/National Gallery
# 1                              NaN
# 2                     Joel Chua DY
# 3                     Joel Chua DY
# 4                              NaN
# ..                             ...
# 104                            NaN
# 105                    Derrick See
# 106                            NaN
# 107         St. James Holdings Ltd
# 108                            NaN
#
#                                            PAGETITLE  \
# 0                         National Gallery Singapore
# 1            Sultan Mosque (Masjid Sultan) Singapore
# 2    Sri Mariamman Temple: Hindu Temple in Singapore
# 3                       Armenian Church in Singapore
# 4                                  CHIJMES Singapore
# ..                                               ...
# 104  MacRitchie Singapore & Singapore Nature Reserve
# 105                               Gardens by the Bay
# 106                        Civic District, Singapore
# 107                          HarbourFront, Singapore
# 108    Bras Basah.Bugis, Singapore Cultural District
#
#                       LASTMODIFIED  LATITUDE  LONGTITUDE  \
# 0    2015-10-23T18:03:40.939+08:00     1.290  103.851356
# 1    2015-11-02T10:27:45.190+08:00     1.302  103.859171
# 2    2015-11-02T10:31:58.848+08:00     1.282  103.845380
# 3    2015-11-02T10:34:55.710+08:00     1.293  103.849660
# 4    2015-11-02T10:13:35.220+08:00     1.295  103.851680
# ..                             ...       ...         ...
# 104  2015-10-15T18:52:17.740+08:00     1.345  103.822346
# 105  2015-10-19T15:26:06.746+08:00     1.282  103.863613
# 106  2015-10-13T14:04:28.278+08:00     1.293  103.852220
# 107  2015-10-12T15:30:50.116+08:00     1.265  103.820570
# 108  2015-10-12T15:34:32.303+08:00     1.301  103.856240
#
#                        ADDRESS POSTALCODE  \
# 0           1 St Andrew's Road        NaN
# 1              3 Muscat Street        NaN
# 2        244 South Bridge Road        NaN
# 3               60 Hill Street        NaN
# 4           30 Victoria Street        NaN
# ..                         ...        ...
# 104  MacRitchie Reservoir Park        NaN
# 105    18 Marina Gardens Drive        NaN
# 106      150 North Bridge Road        NaN
# 107      81 Telok Blangah Road        NaN
# 108        220 Victoria Street        NaN
#
#                                               OVERVIEW  \
# 0    Take in the regionâ€™s newest and largest muse...
# 1    Also known as Masjid Sultan, the impressive Su...
# 2    Located in Chinatown, the Sri Mariamman Temple...
# 3    The oldest Christian church in Singapore is an...
# 4    Whether functioning as a school or a lifestyle...
# ..                                                 ...
# 104  The attractions around MacRitchie Reservoir is...
# 105  This sprawling garden in the city provides mes...
# 106  The Civic District is where Singaporeâ€™s hist...
# 107  HarbourFront is the place to go if you're hopp...
# 108  The Bras Basah.Bugis Precinct is the arts and ...
#
#                                          EXTERNAL_LINK  \
# 0                        http://www.nationalgallery.sg
# 1                       http://www.sultanmosque.org.sg
# 2    http://heb.gov.sg/our-subsidiaries/temples/sri...
# 3                      http://www.armeniansinasia.org/
# 4                               http://chijmes.com.sg/
# ..                                                 ...
# 104  http://www.nparks.gov.sg/cms/macritchie.php?op...
# 105     http://www.gardensbythebay.com.sg/en/home.html
# 106                                                NaN
# 107                            http://www.shba.org.sg/
# 108                      http://www.brasbasahbugis.sg/
#
#                                       META_DESCRIPTION  \
# 0    Take in the regionâ€™s newest and largest muse...
# 1    The impressive Sultan Mosque (also known as Ma...
# 2    Sri Mariamman Temple, located in Chinatown, is...
# 3    The Armenian Church is the oldest Christian ch...
# 4    Who would have thought a former school would m...
# ..                                                 ...
# 104  The attractions around MacRitchie Reservoir ca...
# 105  Gardens by the Bay provides mesmerising waterf...
# 106  The Civic District is where Singaporeâ€™s hist...
# 107  HarbourFront is the place to go if you're hopp...
# 108  The Bras Basah.Bugis Precinct is the vibrant a...
#
#                                          OPENING_HOURS           INC_CRC  \
# 0    Effective from 24 November 2015, Sunday to Thu...  8A41138FE0684CA7
# 1    Monday to Sunday:9.30am â€“ 12pm and 2pm â€“ 4...  A3218DB77F17BFC6
# 2             Daily from 7am â€“ 12pm, and 6pm â€“ 9pm  F66A0BB9C79777F1
# 3                                    Daily, 9am â€“6pm  4C9C762C0E30783B
# 4    Daily, 24 hours,Opening hours of businesses in...  5A0FF621153ABB8F
# ..                                                 ...               ...
# 104                                                NaN  55CEE55B4F6A895A
# 105  Bay South Outdoor Gardens Daily, 5am - 2am Coo...  76915C78CEAAEB32
# 106                                                NaN  6C2A4BCE94CE4175
# 107                                                NaN  D8640AC2A93885F8
# 108                                                NaN  44132C4232BA16E5
#
#          FMEL_UPD_D   longitude  latitude
# 0    20180619175243  103.851356     1.290
# 1    20180619175243  103.859171     1.302
# 2    20180619175243  103.845380     1.282
# 3    20180619175243  103.849660     1.293
# 4    20180619175243  103.851680     1.295
# ..              ...         ...       ...
# 104  20180619175243  103.822346     1.345
# 105  20180619175243  103.863613     1.282
# 106  20180619175243  103.852220     1.293
# 107  20180619175243  103.820570     1.265
# 108  20180619175243  103.856240     1.301
#
# [109 rows x 19 columns]

# %% [markdown]
# Flattening tourist attractions from a **local GeoJSON** (`TouristAttractions.geojson`). That file is **not** in this repo—save/export it next to the notebook or repo root if you use this path. **If you already ran the poll-download cell above**, it left a flattened `df` in memory; the next cell will reuse that when the file is missing.

# %%
import json
from pathlib import Path

import pandas as pd

# Relative paths use the Jupyter kernel cwd (often repo root), not the notebook folder.
_candidates = [
    Path.cwd() / "TouristAttractions.geojson",
    Path.cwd() / "tourist_attraction_ingest" / "TouristAttractions.geojson",
]
_geo_path = next((p for p in _candidates if p.is_file()), None)

if _geo_path is not None:
    with _geo_path.open(encoding="utf-8") as f:
        data = json.load(f)
    rows = []
    for feat in data.get("features", []):
        row = dict(feat.get("properties", {}))
        geom = feat.get("geometry", {}) or {}
        if geom.get("type") == "Point" and "coordinates" in geom:
            row["longitude"] = geom["coordinates"][0]
            row["latitude"] = geom["coordinates"][1]
        rows.append(row)
    df = pd.DataFrame(rows)
elif "df" in globals() and isinstance(df, pd.DataFrame) and len(df) > 0:
    print(
        "TouristAttractions.geojson not found — using existing `df` from the API cell above.\n"
        "Searched:\n  " + "\n  ".join(str(p) for p in _candidates)
    )
else:
    raise FileNotFoundError(
        "TouristAttractions.geojson not found. Searched:\n  "
        + "\n  ".join(str(p) for p in _candidates)
        + "\n\nEither save the GeoJSON to one of those paths, or run the previous cell "
        "that loads data from data.gov.sg (poll-download) so `df` exists."
    )

df
# Out:
# TouristAttractions.geojson not found — using existing `df` from the API cell above.
# Searched:
#   /root/hdb-price-estimator/tourist_attraction_ingest/TouristAttractions.geojson
#   /root/hdb-price-estimator/tourist_attraction_ingest/tourist_attraction_ingest/TouristAttractions.geojson
#      OBJECTID_1                                           URL_PATH  \
# 0          1001  www.yoursingapore.com/en/see-do-singapore/arts...
# 1          1002  www.yoursingapore.com/en/see-do-singapore/cult...
# 2          1003  www.yoursingapore.com/en/see-do-singapore/cult...
# 3          1004  www.yoursingapore.com/en/see-do-singapore/cult...
# 4          1005  www.yoursingapore.com/en/see-do-singapore/arch...
# ..          ...                                                ...
# 104         996  www.yoursingapore.com/en/see-do-singapore/natu...
# 105         997  www.yoursingapore.com/en/see-do-singapore/natu...
# 106         998  www.yoursingapore.com/en/see-do-singapore/plac...
# 107         999  www.yoursingapore.com/en/see-do-singapore/plac...
# 108        1000  www.yoursingapore.com/en/see-do-singapore/plac...
#
#                                             IMAGE_PATH  \
# 0    www.yoursingapore.com/content/dam/desktop/glob...
# 1                                                  NaN
# 2    www.yoursingapore.com/content/dam/desktop/glob...
# 3    www.yoursingapore.com/content/dam/desktop/glob...
# 4    www.yoursingapore.com/content/dam/desktop/glob...
# ..                                                 ...
# 104  www.yoursingapore.com/content/dam/desktop/glob...
# 105  www.yoursingapore.com/content/dam/desktop/glob...
# 106  www.yoursingapore.com/content/dam/desktop/glob...
# 107  www.yoursingapore.com/content/dam/desktop/glob...
# 108  www.yoursingapore.com/content/dam/desktop/glob...
#
#                                         IMAGE_ALT_TEXT  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Sri Mariamman Temple's ornate and elaborate de...
# 3    The Armenian Church in Singapore is a 19th-cen...
# 4    The charm of CHIJMES, Singapore harks back to ...
# ..                                                 ...
# 104  MacRitchie Reservoir is natureâ€™s playground ...
# 105  Be mesmerised by stunning waterfront views at ...
# 106  Immerse yourself in a day of history and cultu...
# 107  HarbourFront, Singapore is your exciting gatew...
# 108  Thereâ€™s nowhere else quite like shopping at ...
#
#                       PHOTOCREDITS  \
# 0    Â©Darren Soh/National Gallery
# 1                              NaN
# 2                     Joel Chua DY
# 3                     Joel Chua DY
# 4                              NaN
# ..                             ...
# 104                            NaN
# 105                    Derrick See
# 106                            NaN
# 107         St. James Holdings Ltd
# 108                            NaN
#
#                                            PAGETITLE  \
# 0                         National Gallery Singapore
# 1            Sultan Mosque (Masjid Sultan) Singapore
# 2    Sri Mariamman Temple: Hindu Temple in Singapore
# 3                       Armenian Church in Singapore
# 4                                  CHIJMES Singapore
# ..                                               ...
# 104  MacRitchie Singapore & Singapore Nature Reserve
# 105                               Gardens by the Bay
# 106                        Civic District, Singapore
# 107                          HarbourFront, Singapore
# 108    Bras Basah.Bugis, Singapore Cultural District
#
#                       LASTMODIFIED  LATITUDE  LONGTITUDE  \
# 0    2015-10-23T18:03:40.939+08:00     1.290  103.851356
# 1    2015-11-02T10:27:45.190+08:00     1.302  103.859171
# 2    2015-11-02T10:31:58.848+08:00     1.282  103.845380
# 3    2015-11-02T10:34:55.710+08:00     1.293  103.849660
# 4    2015-11-02T10:13:35.220+08:00     1.295  103.851680
# ..                             ...       ...         ...
# 104  2015-10-15T18:52:17.740+08:00     1.345  103.822346
# 105  2015-10-19T15:26:06.746+08:00     1.282  103.863613
# 106  2015-10-13T14:04:28.278+08:00     1.293  103.852220
# 107  2015-10-12T15:30:50.116+08:00     1.265  103.820570
# 108  2015-10-12T15:34:32.303+08:00     1.301  103.856240
#
#                        ADDRESS POSTALCODE  \
# 0           1 St Andrew's Road        NaN
# 1              3 Muscat Street        NaN
# 2        244 South Bridge Road        NaN
# 3               60 Hill Street        NaN
# 4           30 Victoria Street        NaN
# ..                         ...        ...
# 104  MacRitchie Reservoir Park        NaN
# 105    18 Marina Gardens Drive        NaN
# 106      150 North Bridge Road        NaN
# 107      81 Telok Blangah Road        NaN
# 108        220 Victoria Street        NaN
#
#                                               OVERVIEW  \
# 0    Take in the regionâ€™s newest and largest muse...
# 1    Also known as Masjid Sultan, the impressive Su...
# 2    Located in Chinatown, the Sri Mariamman Temple...
# 3    The oldest Christian church in Singapore is an...
# 4    Whether functioning as a school or a lifestyle...
# ..                                                 ...
# 104  The attractions around MacRitchie Reservoir is...
# 105  This sprawling garden in the city provides mes...
# 106  The Civic District is where Singaporeâ€™s hist...
# 107  HarbourFront is the place to go if you're hopp...
# 108  The Bras Basah.Bugis Precinct is the arts and ...
#
#                                          EXTERNAL_LINK  \
# 0                        http://www.nationalgallery.sg
# 1                       http://www.sultanmosque.org.sg
# 2    http://heb.gov.sg/our-subsidiaries/temples/sri...
# 3                      http://www.armeniansinasia.org/
# 4                               http://chijmes.com.sg/
# ..                                                 ...
# 104  http://www.nparks.gov.sg/cms/macritchie.php?op...
# 105     http://www.gardensbythebay.com.sg/en/home.html
# 106                                                NaN
# 107                            http://www.shba.org.sg/
# 108                      http://www.brasbasahbugis.sg/
#
#                                       META_DESCRIPTION  \
# 0    Take in the regionâ€™s newest and largest muse...
# 1    The impressive Sultan Mosque (also known as Ma...
# 2    Sri Mariamman Temple, located in Chinatown, is...
# 3    The Armenian Church is the oldest Christian ch...
# 4    Who would have thought a former school would m...
# ..                                                 ...
# 104  The attractions around MacRitchie Reservoir ca...
# 105  Gardens by the Bay provides mesmerising waterf...
# 106  The Civic District is where Singaporeâ€™s hist...
# 107  HarbourFront is the place to go if you're hopp...
# 108  The Bras Basah.Bugis Precinct is the vibrant a...
#
#                                          OPENING_HOURS           INC_CRC  \
# 0    Effective from 24 November 2015, Sunday to Thu...  8A41138FE0684CA7
# 1    Monday to Sunday:9.30am â€“ 12pm and 2pm â€“ 4...  A3218DB77F17BFC6
# 2             Daily from 7am â€“ 12pm, and 6pm â€“ 9pm  F66A0BB9C79777F1
# 3                                    Daily, 9am â€“6pm  4C9C762C0E30783B
# 4    Daily, 24 hours,Opening hours of businesses in...  5A0FF621153ABB8F
# ..                                                 ...               ...
# 104                                                NaN  55CEE55B4F6A895A
# 105  Bay South Outdoor Gardens Daily, 5am - 2am Coo...  76915C78CEAAEB32
# 106                                                NaN  6C2A4BCE94CE4175
# 107                                                NaN  D8640AC2A93885F8
# 108                                                NaN  44132C4232BA16E5
#
#          FMEL_UPD_D   longitude  latitude
# 0    20180619175243  103.851356     1.290
# 1    20180619175243  103.859171     1.302
# 2    20180619175243  103.845380     1.282
# 3    20180619175243  103.849660     1.293
# 4    20180619175243  103.851680     1.295
# ..              ...         ...       ...
# 104  20180619175243  103.822346     1.345
# 105  20180619175243  103.863613     1.282
# 106  20180619175243  103.852220     1.293
# 107  20180619175243  103.820570     1.265
# 108  20180619175243  103.856240     1.301
#
# [109 rows x 19 columns]

# %%
import folium

# Use LATITUDE/LONGTITUDE or latitude/longitude (from geometry)
lat_col = "LATITUDE" if "LATITUDE" in df.columns else "latitude"
lon_col = "LONGTITUDE" if "LONGTITUDE" in df.columns else "longitude"

# Drop rows with missing coordinates
df_map = df.dropna(subset=[lat_col, lon_col])

# Center map on Singapore
m = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

# Add markers
for _, row in df_map.iterrows():
    popup = row.get("PAGETITLE", row.get("ADDRESS", "—"))
    folium.Marker(
        location=[row[lat_col], row[lon_col]],
        popup=str(popup),
        tooltip=str(popup)
    ).add_to(m)

m.save("map.html")
print("Map saved to map.html — open it in your browser")
# Out:
# Map saved to map.html — open it in your browser

# %%
df.columns.tolist()
# Out:
# ['OBJECTID_1',
#  'URL_PATH',
#  'IMAGE_PATH',
#  'IMAGE_ALT_TEXT',
#  'PHOTOCREDITS',
#  'PAGETITLE',
#  'LASTMODIFIED',
#  'LATITUDE',
#  'LONGTITUDE',
#  'ADDRESS',
#  'POSTALCODE',
#  'OVERVIEW',
#  'EXTERNAL_LINK',
#  'META_DESCRIPTION',
#  'OPENING_HOURS',
#  'INC_CRC',
#  'FMEL_UPD_D',
#  'longitude',
#  'latitude']

# %% [markdown]
# ### HDB resale flat prices — dataset size (ingest)
#
# `resale_flat_price` is loaded via **poll-download** (bulk CSV), same as the Airflow DAG. Below: **row count** from CKAN `datastore_search` (cheap, `limit=1`) and **approximate CSV size** from **`Content-Length` on a streaming `GET`** to the presigned S3 URL (no full download). **Do not use `HEAD` on that URL**—S3 presigns are usually **GET-only**, so `HEAD` often returns **403 Forbidden**.

# %%
from pathlib import Path
import sys

# Resolve project root so `tourist_attraction_ingest` imports work (run from repo root or this folder).
_cwd = Path.cwd()
for base in (_cwd, _cwd.parent):
    if (base / "tourist_attraction_ingest" / "dag_helpers.py").is_file():
        if str(base) not in sys.path:
            sys.path.insert(0, str(base))
        break
else:
    raise ImportError("Could not find tourist_attraction_ingest/dag_helpers.py — open notebook from hdb-price-estimator or tourist_attraction_ingest.")

from tourist_attraction_ingest import dag_helpers

SOURCES = dag_helpers.SOURCES
session = dag_helpers._http_session()  # retries on 429 for data.gov.sg

cfg = SOURCES["resale_flat_price"]
dataset_id = cfg["dataset_id"]
api_base = cfg["api_base"].rstrip("/")

# --- 1) Row count (CKAN; same resource id, minimal payload) ---
ckan = session.get(
    "https://data.gov.sg/api/action/datastore_search",
    params={"resource_id": dataset_id, "limit": 1},
    timeout=120,
)
ckan.raise_for_status()
body = ckan.json()
res = body.get("result") or {}
total_rows = res.get("total")
sample_cols = list((res.get("records") or [{}])[0].keys()) if res.get("records") else []

# --- 2) Approx. CSV bytes (same poll-download path as Airflow) ---
poll = session.get(f"{api_base}/{dataset_id}/poll-download", timeout=120)
poll.raise_for_status()
pj = poll.json()
code = pj.get("code")
csv_url = (pj.get("data") or {}).get("url")
csv_bytes = None
if csv_url:
    # Presigned S3 URLs are signed for GET. HEAD is a different HTTP method and often returns 403.
    with session.get(csv_url, stream=True, allow_redirects=True, timeout=300) as gr:
        gr.raise_for_status()
        cl = gr.headers.get("Content-Length")
        if cl is not None:
            csv_bytes = int(cl)

def _fmt_bytes(n: int) -> str:
    if n < 1024:
        return f"{n} B"
    val = float(n)
    for unit in ("KiB", "MiB", "GiB"):
        val /= 1024.0
        if val < 1024.0 or unit == "GiB":
            return f"{val:.2f} {unit}"
    return f"{n} B"

print("resale_flat_price (SOURCES key)")
print(f"  dataset_id / resource_id: {dataset_id}")
print(f"  CKAN total rows (datastore_search): {total_rows}")
if sample_cols:
    print(f"  sample columns ({len(sample_cols)}): {sample_cols[:8]}{' ...' if len(sample_cols) > 8 else ''}")
print(f"  poll-download API code: {code}")
if csv_bytes is not None:
    print(f"  CSV Content-Length (GET): {_fmt_bytes(csv_bytes)} ({csv_bytes:,} bytes)")
else:
    print("  CSV size: Content-Length not in GET response headers (chunked/unknown)")
if total_rows and csv_bytes:
    approx = csv_bytes / total_rows
    print(f"  ~ {approx:.1f} bytes/row (CSV; rough)")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 44
#      42 if csv_url:
#      43     head = session.head(csv_url, allow_redirects=True, timeout=120)
# ---> 44     head.raise_for_status()
#      45     cl = head.headers.get("Content-Length")
#      46     if cl is not None:
#
# File ~/hdb-price-estimator/venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://s3.ap-southeast-1.amazonaws.com/table-downloads-ingest.data.gov.sg/d_8b84c4ee58e3cfc0ece0d773c8ca6abc/6f8109f7bce05c219b3825a999cc7f3a02cbc19fe536138a5eaf86bfe6d8711f.csv?AWSAccessKeyId=ASIAU7LWPY2WNO5N5VRK&Expires=1773986550&Signature=6LwnyK28XscYM3FfV14hG%2B11DVA%3D&X-Amzn-Trace-Id=Root%3D1-69bcd4e5-62e684827cabb4b2274668f0%3BParent%3Dca68bcfb5b17f5b5%3BSampled%3D0%3BLineage%3D1%3Affb76583%3A0&response-content-disposition=attachment%3B%20filename%3D%22ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv%22&x-amz-security-token=IQoJb3JpZ2luX2VjEGUaDmFwLXNvdXRoZWFzdC0xIkcwRQIgBn2hEI2%2B8fhpUKoCh7kv48I%2FyL2uwQNZYgbiWo9PE5gCIQCkGoelpywoQRfvIeRCjzB5XBAdUerhOAz%2FdBzJBHKUniq7BAguEAQaDDM0MjIzNTI2ODc4MCIM3gsAVm6t%2Bn0YpRJTKpgEbfn3nQivVgcGuT3EUpm2wk0O35VOceBIMAeo8mZyEHGkHy4%2B6bGSqee%2BXiydmcmlsa5hp2XGN6CQyVOCtLA5HZcPecMJKLwF7w4zzTuZtc5kYc9UIITN8mjI4m9jMqBQQUhD%2FBqeskOUJmNWuUjpsU229oKyfmmqlhxhqrkuBs6wwVbDMruEhFPIJ3zz2PfvWo%2FAp6cSVzigfqyLiYyfXrpvAINdTHyPxIccW5PBMwfjvXA%2FzVn3O%2BxWdcrJHGFA8pN56WPD7dzq8SjzRIdunSFUR%2F4fIliWKpPKW4g%2F5jS6nsn82HipkHzfVUW34raa7xfQsc72aS189a3qVz9HbjlT4mi%2BTlbKBDm8TKoPDCkfyRla67DqNjSZbnB8dlSw5fvp3zrbWHEQc%2Bs%2Fhv12wNgX6l%2BF29ulquZZ1Xu7Uuw7%2BJ2xKGpQ%2FzzC2n36vs6SToICAxVPVQ34m8Mh6N%2B9vCF92Drvh95NbybX9x0XV2rdmzw%2B4hDnT1ztfwe%2FRPNTw65KZlyBF7XFW88EYxdPwHJYOhqwer2GNPJi1VCG3Nf8FdAvyvDzeicvlO%2BPzu51Qwqc2%2FJ2Rg6JJYJeqNH4r5yOMtFmnsCsoOrzHX1W5HKCwK0K57Ac91iULdR8Xk%2Fz3QRCuBeq0gsnOK6ffx9GCMP2qTmMJ6EIpvTC6%2ByZciZ0BCt5ix7IPvAvr3jP%2BxoYJvaOxZXyReQw%2BJzzzQY6ogGi0MX0W9kC3AH2mx8g12f5yJvosou8TfZpl%2FJ31RkI7COQT1qcA8G64Kzj4X%2FQ7551lUDMl%2BaI4S6ye2oyONIBan1HplviCdJ2ENix4c6ZIPZ5SpOhGnYI8Px5UjCipLmZpxftgnRSts1rIqkwWHIYf2kGwukntfM5Vep9S3pSCs7rg4PsmD3ynqM9%2FXgM2qHCwEnmwXIfWM7w7rymGj5oNd0%3D
